# %%
# 1.-Load module
import sqlalchemy
import pandas as pd
#2.-Turn on database engine
dbEngine=sqlalchemy.create_engine('sqlite:///instance/people.db') # ensure this is the correct path for the sqlite file. 

#3.- Read data with pandas
pd.read_sql('select * from test', dbEngine)

#4.- I also want to add a new table from a dataframe in sqlite (a small one) 
# df_todb.to_sql(name = 'newTable',con= dbEngine, index=False, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\sjuan\Documents\GitHub\text_to_speech\t2sEnv\Lib\site-packages\sqlalchemy\engine\base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#
# File c:\Users\sjuan\Documents\GitHub\text_to_speech\t2sEnv\Lib\site-packages\sqlalchemy\engine\default.py:736, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     735 def do_execute(self, cursor, statement, parameters, context=None):
# --> 736     cursor.execute(statement, parameters)
#
# OperationalError: no such table: test
#
# ...
